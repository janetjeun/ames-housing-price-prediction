# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Ames Housing Sale <br>
# **Notebook 1: Data Cleaning**

# %% [markdown]
# # EXECUTIVE SUMMARY

# %% [markdown]
# IowaGuru is a property agent company in United States based in Ames, Iowa. We are tasked to predict the prices of future listings so that we may give potential customers a quick and reliable estimate of their property value before they engage us to find a buyer. In addition, IowaGuru would also like to find out the key information to collect for future house listings. The model will be built using Ames Housing Dataset from 2006 to 2010.
#
# During the data cleaning process & EDA, missing values are imputed, and graphs are plotted to identify outliers in the datasets, and addressed accordingly. During Pre-processing, ordinal features and nominal features are encoded. Split train-test and data transformations were done and Baseline Model were developed using Linear Regression, Lasso, Ridge, and ElasticNet.
#
# When developing the Baseline Model, we found that Overall Quality, External Quality, and Ground Living Area exhibits a strong relationship with Sale Prices. Lasso Regression gave us the best results, with Ridge Regression as a close second in our Baseline Model. The Baseline Model's Lasso RMSE score is 24167.
#
# During data processing and feature engineering, a new feature 'House Quality' were created by combining Kitchen Quality, Basement Quality, and Overall Quality features. The final regression model also incorporates hyperparameter tuning to achieve the best results. The final Lasso RMSE score is 21991.
#
# From the analysis, the top 5 features that corresponds positively with SalePrices are: Ground Living Area, Overall Quality, Kitchen Quality, Basement Quality and External Quality. The top 5 features that corresponds negatively with SalePrices are: House Age, N.A. Mas Vnr Type, Detatched Garage Type, CBlock Foundation, and Lot Shape.

# %% [markdown]
# # 00. INTRODUCTION

# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# Ames is a city in Story County, Iowa, United States, located approximately 30 miles north of Des Moines in central Iowa. It is best known as the home of Iowa State University, with leading agriculture, design, engineering, and veterinary medicine colleges. Ames had a population of 66,427, making it the state's ninth largest city. ([*source*](https://en.wikipedia.org/wiki/Ames,_Iowa)).
#
# IowaGuru is a property agent company in United States based in New York, and would like to expand their base in Ames, Iowa. As data scientist working in IowaGuru, We are tasked to predict the prices of future listings so that they may give potential customers a quick and reliable estimate of their property value before they engage them to find a buyer. In addition, IowaGuru would also tasked us to find out the key information to collect for future house listings.
#
# The model will be built using [*Ames Housing Dataset*](https://www.kaggle.com/competitions/dsi-us-11-project-2-regression-challenge/data), and [*Data Dictionary*](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt). In this analysis, we will be using Linear Regression, Lasso, Ridge, and ElasticNet will be developed. Model with highest Train/Test score, highest CrossVal score, as well as lowest RMSE score will then be selected to predict the housing price.

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# **1. Data Cleaning (This Notebook)** <br>
# - [01. Library and Data Import](#01.-LIBRARY-AND-DATA-IMPORT) <br>
# - [02. Data Cleaning](#02.-DATA-CLEANING) <br>
# - [03. Nominal Data Encoding](#03.-ORDINAL-DATA-ENCODING) <br>
# - [04. Summary](#05.-SUMMARY) <br>
# - [05. Export Cleaned Data](#06.-EXPORT-CLEANED-DATA) <br>
#
# **2. EDA & Baseline Model** <br>
# **3. Model Tuning & Kaggle Submission** <br>

# %% [markdown]
# # 01. LIBRARY AND DATA IMPORT

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import sklearn libraries

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LassoCV, Ridge, RidgeCV, ElasticNet
from sklearn.preprocessing import StandardScaler

# %%
# import datasets
df_test = pd.read_csv('../datasets/test.csv')
df = pd.read_csv('../datasets/train.csv')

# %% [markdown]
# # 02. DATA CLEANING

# %% [markdown]
# ## A. TRAIN DATASET (df)

# %% [markdown]
# ### I. Data Overview

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#                  Id           PID  MS SubClass MS Zoning  Lot Frontage  \
# count   2051.000000  2.051000e+03  2051.000000      2051   1721.000000
# unique          NaN           NaN          NaN         7           NaN
# top             NaN           NaN          NaN        RL           NaN
# freq            NaN           NaN          NaN      1598           NaN
# mean    1474.033642  7.135900e+08    57.008776       NaN     69.055200
# std      843.980841  1.886918e+08    42.824223       NaN     23.260653
# min        1.000000  5.263011e+08    20.000000       NaN     21.000000
# 25%      753.500000  5.284581e+08    20.000000       NaN     58.000000
# 50%     1486.000000  5.354532e+08    50.000000       NaN     68.000000
# 75%     2198.000000  9.071801e+08    70.000000       NaN     80.000000
# max     2930.000000  9.241520e+08   190.000000       NaN    313.000000
#
#              Lot Area Street Alley Lot Shape Land Contour Utilities  \
# ...

# %% [markdown]
# **Observations:**
# 1. The average SalePrice is 180k, minimum SalePrice is 12k, and maximum SalePrice is 610k
# 2. There are 2051 datas with 80 features in this dataset
# 3. Some features have missing datas
# 4. There are some features marked as 'NA' but was read as 'None'
# 5. All data types seems to be correct
# 6. Max value for 'Garage Yr Blt' is 2207, which is impossible

# %%
missing_values = (df.isnull().sum() / len(df)) * 100
missing_values = missing_values.to_frame(name = 'Percentage of Missing Value')

# %%
missing_values = missing_values.sort_values(by = 'Percentage of Missing Value', ascending = False).head(10)

# %%
fig, ax = plt.subplots()
ax = sns.barplot(data = missing_values, y = missing_values.index, x = 'Percentage of Missing Value')
ax.set_ylabel('Features')
ax.set_xlabel('Percent')
ax.set_title('Percentage of Values Missing')
plt.show()

# %% [markdown]
# **Observations:** <br>
# 'Pool QC', 'Misc Feature', 'Alley' and 'Fence' has a lot of missing value (more than 80%). <br>
# 'Fireplace Qu' also has about 50% of data missing. <br>
# Referring to the data dictionary, this simply means that there is no pool / no misc feature / no alley / no fence.

# %% [markdown]
# ### II. Data Cleaning

# %% [markdown]
# #### Drop Id and PID

# %%
# drop Id and PID as it is not usefull for our analysis

df.drop(["Id", "PID"], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2051 non-null   int64
#  1   MS Zoning        2051 non-null   object
#  2   Lot Frontage     1721 non-null   float64
#  3   Lot Area         2051 non-null   int64
#  4   Street           2051 non-null   object
#  5   Alley            140 non-null    object
#  6   Lot Shape        2051 non-null   object
#  7   Land Contour     2051 non-null   object
#  8   Utilities        2051 non-null   object
#  9   Lot Config       2051 non-null   object
#  10  Land Slope       2051 non-null   object
#  11  Neighborhood     2051 non-null   object
#  12  Condition 1      2051 non-null   object
#  13  Condition 2      2051 non-null   object
#  14  Bldg Type        2051 non-null   object
#  15  House Style      2051 non-null   object
# ...

# %% [markdown]
# #### Replace 'NaN' to 'N.A.'

# %%
# Our datasets: float64(11), int64(26), object(42)
# Let's review object data type first

for x in df.select_dtypes(include='object'):
    print(x, df[x].unique())
# Out:
# MS Zoning ['RL' 'RM' 'FV' 'C (all)' 'A (agr)' 'RH' 'I (all)']
# Street ['Pave' 'Grvl']
# Alley [nan 'Pave' 'Grvl']
# Lot Shape ['IR1' 'Reg' 'IR2' 'IR3']
# Land Contour ['Lvl' 'HLS' 'Bnk' 'Low']
# Utilities ['AllPub' 'NoSeWa' 'NoSewr']
# Lot Config ['CulDSac' 'Inside' 'Corner' 'FR2' 'FR3']
# Land Slope ['Gtl' 'Sev' 'Mod']
# Neighborhood ['Sawyer' 'SawyerW' 'NAmes' 'Timber' 'Edwards' 'OldTown' 'BrDale'
#  'CollgCr' 'Somerst' 'Mitchel' 'StoneBr' 'NridgHt' 'Gilbert' 'Crawfor'
#  'IDOTRR' 'NWAmes' 'Veenker' 'MeadowV' 'SWISU' 'NoRidge' 'ClearCr'
#  'Blmngtn' 'BrkSide' 'NPkVill' 'Blueste' 'GrnHill' 'Greens' 'Landmrk']
# Condition 1 ['RRAe' 'Norm' 'PosA' 'Artery' 'Feedr' 'PosN' 'RRAn' 'RRNe' 'RRNn']
# Condition 2 ['Norm' 'RRNn' 'Feedr' 'Artery' 'PosA' 'PosN' 'RRAe' 'RRAn']
# Bldg Type ['1Fam' 'TwnhsE' 'Twnhs' '2fmCon' 'Duplex']
# House Style ['2Story' '1Story' '1.5Fin' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin' '1.5Unf']
# Roof Style ['Gable' 'Hip' 'Flat' 'Mansard' 'Shed' 'Gambrel']
# ...

# %% [markdown]
# **Observations:** <br>
# There are 3 category for Alley:
# 1. 'Pave' : Paved
# 2. 'Grvl' : Gravel
# 3. 'N.A.' for No alley access <br>
# However, N.A. is registered as null value <br>
#
# **Applicable to:** Alley, Bsmt Qual, Bsmt Cond, BsmtFin Type 1, BsmtFin Type 2, Fireplace Qu, Garage Finish, Garage Qual, Garage Cond, Pool QC, Fence, Misc Feature

# %%
# Convert None to "N.A."

NA_list = ["Alley", "Bsmt Qual", "Bsmt Cond", "BsmtFin Type 1", "BsmtFin Type 2", "Fireplace Qu",
           "Garage Type", "Garage Finish", "Garage Qual", "Garage Cond", "Pool QC", "Fence", "Misc Feature"]

for item in NA_list:
    df[item] = df[item].fillna("N.A.")

# %%
# Check if "N.A." has been changed successfully
df.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           60        RL           NaN     13517   Pave  N.A.       IR1
# 1           60        RL          43.0     11492   Pave  N.A.       IR1
# 2           20        RL          68.0      7922   Pave  N.A.       Reg
# 3           60        RL          73.0      9802   Pave  N.A.       Reg
# 4           50        RL          82.0     14235   Pave  N.A.       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 2          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 4          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# ...

# %%
# Mas Vnr Type "None" change to "NA" for consistency

df.loc[df["Mas Vnr Type"] == "None", "Mas Vnr Type"] = "N.A."

# %% [markdown]
# #### Replacing Missing Dataset

# %%
# display null value in the dataset

def display_null (df):
    null_count = pd.isnull(df).sum()
    is_null = null_count > 0
    return null_count[is_null]

# %%
display_null(df)
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Exposure      58
# BsmtFin SF 1        1
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Yr Blt     114
# Garage Cars         1
# Garage Area         1
# dtype: int64

# %%
# Display those with Garage Area with null value

df[df["Garage Area"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1712           70        RM          50.0      9060   Pave  N.A.       Reg
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1712          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 1712        Norm      1Fam      2Story             5             6
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 1712        1923            1999      Gable   CompShg      Wd Sdng
#
#      Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 1712      Plywood         N.A.           0.0         TA         TA     BrkTil
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1712        Gd        TA            No            ALQ         548.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# ...

# %%
# "Garage Area" and "Garage Cars" shall be 0 instead of None for this case

df["Garage Area"] = df["Garage Area"].fillna(0)
df["Garage Cars"] = df["Garage Cars"].fillna(0)

# %%
display_null(df)
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Exposure      58
# BsmtFin SF 1        1
# BsmtFin SF 2        1
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Yr Blt     114
# dtype: int64

# %%
df[df["BsmtFin SF 1"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1327           20        RM          99.0      5940   Pave  N.A.       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 1327        Norm      1Fam      1Story             4             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 1327       CBlock         N.A.           0.0         TA         TA      PConc
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1327      N.A.      N.A.           NaN           N.A.           NaN
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# ...

# %%
# The "Bsmt Qual" is NA, meaning that there is no basement,
# Hence the "BsmtFin SF 1", "BsmtFin SF 2", "Bsmt Unf SF", "Total Bsmt SF" should be 0

df["BsmtFin SF 1"] = df["BsmtFin SF 1"].fillna(0)
df["BsmtFin SF 2"] = df["BsmtFin SF 2"].fillna(0)
df["Bsmt Unf SF"] = df["Bsmt Unf SF"].fillna(0)
df["Total Bsmt SF"] = df["Total Bsmt SF"].fillna(0)

# %%
display_null(df)
# Out:
# Lot Frontage      330
# Mas Vnr Type       22
# Mas Vnr Area       22
# Bsmt Exposure      58
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Garage Yr Blt     114
# dtype: int64

# %%
df[df["Bsmt Full Bath"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 616            20        RL         123.0     47007   Pave  N.A.       IR1
# 1327           20        RM          99.0      5940   Pave  N.A.       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 616           Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 616         Norm      1Fam      1Story             5             7
# 1327        Norm      1Fam      1Story             4             7
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 616         1959            1996      Gable   CompShg      Plywood
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# ...

# %%
# The "Bsmt Qual" is NA, meaning that there is no basement,
# Hence the "Bsmt Full Bath", "Bsmt Half Bath" should be 0

df["Bsmt Full Bath"] = df["Bsmt Full Bath"].fillna(0)
df["Bsmt Half Bath"] = df["Bsmt Half Bath"].fillna(0)

# %%
display_null(df)
# Out:
# Lot Frontage     330
# Mas Vnr Type      22
# Mas Vnr Area      22
# Bsmt Exposure     58
# Garage Yr Blt    114
# dtype: int64

# %%
# Check "Mas Vnr Area" data

df[df["Mas Vnr Area"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 22             60        RL         103.0     12867   Pave  N.A.       IR1
# 41             20        RL         107.0     13891   Pave  N.A.       Reg
# 86             20        RL          67.0     10083   Pave  N.A.       Reg
# 212            20        FV          90.0      7993   Pave  N.A.       IR1
# 276            20        RL          75.0      8050   Pave  N.A.       Reg
# 338            60        FV         112.0     12217   Pave  N.A.       IR1
# 431            60        RL          75.0      9473   Pave  N.A.       Reg
# 451            20        RL          87.0     10037   Pave  N.A.       Reg
# 591           120        FV          35.0      4274   Pave  Pave       IR1
# 844           120        FV          30.0      5330   Pave  Pave       IR2
# 913            20        RL           NaN     32668   Pave  N.A.       IR1
# ...

# %% [markdown]
# **Observations:**
# As shown from above, the "Mas Vnr Type" and "Mas Vnr Area" is missing. It could mean two things:
# 1. There's no Masonry --> "Mas Vnr Type" = "NA", "Mas Vnr Area" = 0
# 2. There's Masonry but the data was not imputed <br>
#
# However, as both "Mas Vnr Type" and "Mas Vnr Area" are missing together, option 1 is more likely

# %%
# Assign "Mas Vnr Type" None to NA
# Assign "Mas Vnr Area" None to 0

df["Mas Vnr Type"] = df["Mas Vnr Type"].fillna("N.A.")
df["Mas Vnr Area"] = df["Mas Vnr Area"].fillna(0)

# %%
display_null(df)
# Out:
# Lot Frontage     330
# Bsmt Exposure     58
# Garage Yr Blt    114
# dtype: int64

# %%
# Check Bsmt Exposure Data

df[df["Bsmt Exposure"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 12             70        RL         120.0     26400   Pave  N.A.       Reg
# 93             90        RL          64.0      7018   Pave  N.A.       Reg
# 114            20        RL           NaN      9000   Pave  N.A.       Reg
# 146            85        RL          64.0      7301   Pave  N.A.       Reg
# 183            20   A (agr)          80.0     14584   Pave  N.A.       Reg
# 240            20        RL          80.0     12048   Pave  N.A.       Reg
# 249            50        RM          64.0     11067   Pave  N.A.       Reg
# 256            20        RL          77.0      8335   Pave  N.A.       Reg
# 390            90        RM          68.0      8930   Pave  N.A.       Reg
# 437            90        RL          65.0      6040   Pave  N.A.       Reg
# 485            20        RL          60.0      7200   Pave  N.A.       Reg
# ...

# %%
df["Bsmt Exposure"].unique()
# Out:
# array(['No', 'Gd', 'Av', nan, 'Mn'], dtype=object)

# %% [markdown]
# **Obeservations:**
# 1. If there's no basement ("Bsmt Qual" = "NA"), the "Bsmt Exposure" should be "NA" instead of None
# 2. If there's a basement, but there's no exposure, the "Bsmt Exposure" should be "No"

# %%
df.loc[(df["Bsmt Qual"] == "N.A.") & (df["Bsmt Exposure"].isnull()), "Bsmt Exposure"] = "N.A."

# %%
# Display the remaining datasets

df[df["Bsmt Exposure"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1456           60        FV          81.0     10411   Pave  N.A.       Reg
# 1547           20        RL          73.0      8987   Pave  N.A.       Reg
# 1997           60        RL          65.0     14006   Pave  N.A.       IR1
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1456          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1547          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1997          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 1456        Norm      1Fam      2Story             5             5
# 1547        Norm      1Fam      1Story             8             5
# 1997        Norm      1Fam      2Story             7             5
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# ...

# %%
df.loc[df["Bsmt Exposure"].isnull(), "Bsmt Exposure"] = "No"

# %%
df["Bsmt Exposure"].unique()
# Out:
# array(['No', 'Gd', 'Av', 'N.A.', 'Mn'], dtype=object)

# %%
display_null(df)
# Out:
# Lot Frontage     330
# Garage Yr Blt    114
# dtype: int64

# %%
# Check house with garage that has missing value for 'Garage Yr Blt'
df.loc[(df["Garage Yr Blt"].isnull()) & (df["Garage Type"] != "N.A.")]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1712           70        RM          50.0      9060   Pave  N.A.       Reg
#
#      Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 1712          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 1712        Norm      1Fam      2Story             5             6
#
#       Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 1712        1923            1999      Gable   CompShg      Wd Sdng
#
#      Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 1712      Plywood         N.A.           0.0         TA         TA     BrkTil
#
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 1712        Gd        TA            No            ALQ         548.0
#
#      BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# ...

# %%
# Data shown above are not consistent for the garage, let's drop them as there's only 1 row

df.drop(df.loc[(df["Garage Yr Blt"].isnull()) & (df["Garage Type"] != "N.A.")].index, inplace = True)

# %%
# House with no garage ('Garage Type' is N.A.) -- Year built should be None
df.loc[(df["Garage Yr Blt"].isnull()) & (df["Garage Type"] == "N.A."), "Garage Yr Blt"] = None

# %%
# as observed earlier, the max value of "Garage Yr Blt" is 2207, which is impossible.
# let's drop this row

df.drop(df.loc[df["Garage Yr Blt"] == 2207, ].index, inplace = True)

# %%
df["Garage Yr Blt"].unique()
# Out:
# array([1976., 1997., 1953., 2007., 1957., 1966., 2005., 1959., 1952.,
#        1969., 1971., 1900., 2000., 2004., 1916., 1963., 1977., 2009.,
#        1968., 1992., 1955., 1961., 1973., 1937.,   nan, 2003., 1981.,
#        1931., 1995., 1958., 1965., 2006., 1978., 1954., 1935., 1951.,
#        1996., 1999., 1920., 1930., 1924., 1960., 1949., 1986., 1956.,
#        1994., 1979., 1964., 2001., 1972., 1939., 1962., 1927., 1948.,
#        1967., 1993., 2010., 1915., 1987., 1970., 1988., 1982., 1941.,
#        1984., 1942., 1950., 2002., 1975., 2008., 1974., 1998., 1918.,
#        1938., 1985., 1923., 1980., 1991., 1946., 1940., 1990., 1896.,
#        1983., 1914., 1945., 1921., 1925., 1926., 1936., 1932., 1947.,
#        1929., 1910., 1917., 1922., 1934., 1989., 1928., 1933., 1895.,
#        1919.])

# %%
display_null(df)
# Out:
# Lot Frontage     330
# Garage Yr Blt    113
# dtype: int64

# %%
len(df.loc[df["Garage Yr Blt"] == df["Year Built"], ]) / len(df)
# Out:
# 0.7632991703269888

# %% [markdown]
# As shown from above, 76% of the house built the garage in the same year as they built the house. <br>
# Hence, we should replace the missing "Garage Yr Blt" with "Year Built".

# %%
df.loc[df["Garage Yr Blt"].isnull(), "Garage Yr Blt"] = df["Year Built"]

# %%
display_null(df)
# Out:
# Lot Frontage    330
# dtype: int64

# %% [markdown]
# **Observations:** <br>
# There are 330 datas missing for 'Lot Frontage'.
# Lot Frontage (Continuous): Linear feet of street connected to property <br>
# Missing lot frontage simply means that there is no street connected to the property, hence value = 0

# %%
df.loc[df["Lot Frontage"].isnull(), "Lot Frontage"] = 0

# %%
display_null(df)
# Out:
# Series([], dtype: int64)

# %%
df.reset_index(inplace = True, drop=True)

# %% [markdown]
# ## B. TEST DATASET (df_test)

# %% [markdown]
# ### I. Data Overview

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               878 non-null    int64
#  1   PID              878 non-null    int64
#  2   MS SubClass      878 non-null    int64
#  3   MS Zoning        878 non-null    object
#  4   Lot Frontage     718 non-null    float64
#  5   Lot Area         878 non-null    int64
#  6   Street           878 non-null    object
#  7   Alley            58 non-null     object
#  8   Lot Shape        878 non-null    object
#  9   Land Contour     878 non-null    object
#  10  Utilities        878 non-null    object
#  11  Lot Config       878 non-null    object
#  12  Land Slope       878 non-null    object
#  13  Neighborhood     878 non-null    object
#  14  Condition 1      878 non-null    object
#  15  Condition 2      878 non-null    object
#  16  Bldg Type        878 non-null    object
# ...

# %%
df_test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
df_test.describe(include='all')
# Out:
#                  Id           PID  MS SubClass MS Zoning  Lot Frontage  \
# count    878.000000  8.780000e+02   878.000000       878    718.000000
# unique          NaN           NaN          NaN         6           NaN
# top             NaN           NaN          NaN        RL           NaN
# freq            NaN           NaN          NaN       674           NaN
# mean    1444.749431  7.162867e+08    58.268793       NaN     69.545961
# std      850.838263  1.889103e+08    42.235407       NaN     23.533945
# min        2.000000  5.263021e+08    20.000000       NaN     21.000000
# 25%      692.250000  5.284841e+08    20.000000       NaN     59.000000
# 50%     1433.000000  5.354542e+08    50.000000       NaN     68.000000
# 75%     2197.500000  9.071904e+08    70.000000       NaN     80.000000
# max     2928.000000  1.007100e+09   190.000000       NaN    182.000000
#
#              Lot Area Street Alley Lot Shape Land Contour Utilities  \
# ...

# %% [markdown]
# **Observations:**
# 1. There are 878 datas with 79 features in this dataset (No 'SalePrice')
# 2. Some features have missing datas
# 3. There are some features marked as 'NA' but was read as 'None'
# 4. All data types seems to be correct

# %%
missing_values_test = (df_test.isnull().sum() / len(df_test)) * 100
missing_values_test = missing_values_test.to_frame(name = 'Percentage of Missing Value')

# %%
missing_values_test = missing_values_test.sort_values(by = 'Percentage of Missing Value', ascending = False).head(10)

# %%
fig, ax = plt.subplots()
ax = sns.barplot(data = missing_values_test, y = missing_values_test.index, x = 'Percentage of Missing Value')
ax.set_ylabel('Features')
ax.set_xlabel('Percent')
ax.set_title('Percentage of Values Missing')
plt.show()

# %% [markdown]
# **Observations:** <br>
# 'Pool QC', 'Misc Feature', 'Alley' and 'Fence' has a lot of missing value (more than 80%). <br>
# 'Fireplace Qu' also has about 50% of data missing. <br>
# However, this simply means that there is no pool / no misc feature / no alley / no fence.

# %% [markdown]
# ### II. Data Cleaning

# %% [markdown]
# #### Replace 'NaN' to 'N.A.'

# %%
display_null(df_test)
# Out:
# Lot Frontage      160
# Alley             820
# Mas Vnr Type        1
# Mas Vnr Area        1
# Bsmt Qual          25
# Bsmt Cond          25
# Bsmt Exposure      25
# BsmtFin Type 1     25
# BsmtFin Type 2     25
# Electrical          1
# Fireplace Qu      422
# Garage Type        44
# Garage Yr Blt      45
# Garage Finish      45
# Garage Qual        45
# Garage Cond        45
# Pool QC           874
# Fence             706
# Misc Feature      837
# dtype: int64

# %%
# Our datasets: float64, int64, object
# Let's review object data type first

for x in df_test.select_dtypes(include='object'):
    print(x, df_test[x].unique())
# Out:
# MS Zoning ['RM' 'RL' 'FV' 'RH' 'C (all)' 'I (all)']
# Street ['Pave' 'Grvl']
# Alley ['Grvl' nan 'Pave']
# Lot Shape ['Reg' 'IR1' 'IR3' 'IR2']
# Land Contour ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities ['AllPub' 'NoSewr']
# Lot Config ['Inside' 'CulDSac' 'Corner' 'FR2' 'FR3']
# Land Slope ['Gtl' 'Mod' 'Sev']
# Neighborhood ['OldTown' 'Sawyer' 'Gilbert' 'NAmes' 'MeadowV' 'CollgCr' 'Somerst'
#  'Mitchel' 'SawyerW' 'IDOTRR' 'BrkSide' 'Edwards' 'ClearCr' 'NWAmes'
#  'Timber' 'NoRidge' 'NridgHt' 'Crawfor' 'StoneBr' 'Veenker' 'BrDale'
#  'SWISU' 'Blmngtn' 'NPkVill' 'Greens' 'Blueste']
# Condition 1 ['Norm' 'Feedr' 'Artery' 'PosA' 'RRAn' 'RRNn' 'RRAe' 'RRNe' 'PosN']
# Condition 2 ['Norm' 'Feedr' 'PosA']
# Bldg Type ['2fmCon' 'Duplex' '1Fam' 'TwnhsE' 'Twnhs']
# House Style ['2Story' '1Story' '1.5Fin' 'SLvl' 'SFoyer' '2.5Fin' '2.5Unf' '1.5Unf']
# Roof Style ['Gable' 'Hip' 'Gambrel' 'Flat' 'Mansard' 'Shed']
# Roof Matl ['CompShg' 'Metal' 'WdShake' 'Tar&Grv' 'WdShngl' 'Roll']
# ...

# %% [markdown]
# Do the data cleaning similar to Train Dataset by converting "None" to "NA" <br>
#
# **Applicable to:** Alley, Bsmt Qual, Bsmt Cond, BsmtFin Type 1, BsmtFin Type 2, Fireplace Qu, Garage Finish, Garage Qual, Garage Cond, Pool QC, Fence, Misc Feature
#
# **Not Applicable to:** Electrical (this is missing value)

# %%
# Convert None to "N.A."

NA_list = ["Alley", "Bsmt Qual", "Bsmt Cond", "BsmtFin Type 1", "Bsmt Exposure", "BsmtFin Type 2", "Fireplace Qu",
           "Garage Type", "Garage Finish", "Garage Qual", "Garage Cond", "Pool QC", "Fence", "Misc Feature"]

for item in NA_list:
    df_test[item] = df_test[item].fillna("N.A.")

# %%
df_test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1  N.A.       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2  N.A.       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3  N.A.       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4  N.A.       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
display_null(df_test)
# Out:
# Lot Frontage     160
# Mas Vnr Type       1
# Mas Vnr Area       1
# Electrical         1
# Garage Yr Blt     45
# dtype: int64

# %% [markdown]
# #### Replacing Missing Dataset

# %%
# Manually fill in "Electrical" with the most common electrical type in trained dataset
df_test[df_test["Electrical"].isnull()]
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 634  1578  916386080           80        RL          73.0      9735   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 634  N.A.       Reg          Lvl    AllPub     Inside        Gtl       Timber
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 634        Norm        Norm      1Fam        SLvl             5             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 634        2006            2007      Gable   CompShg      VinylSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 634      VinylSd         None           0.0         TA         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 634        Gd        TA            No            Unf             0
#
# ...

# %%
# Check which "Electrical" is the most common in trained dataset
df["Electrical"].value_counts()
# Out:
# SBrkr    1866
# FuseA     140
# FuseF      35
# FuseP       7
# Mix         1
# Name: Electrical, dtype: int64

# %%
df_test["Electrical"].value_counts()
# Out:
# SBrkr    813
# FuseA     48
# FuseF     15
# FuseP      1
# Name: Electrical, dtype: int64

# %%
df_test.loc[df_test["Electrical"].isnull(), "Electrical"] = "SBrkr"

# %%
display_null(df_test)
# Out:
# Lot Frontage     160
# Mas Vnr Type       1
# Mas Vnr Area       1
# Garage Yr Blt     45
# dtype: int64

# %%
# Manually fill in "Mas Vnr Type" & "Mass Vnr Area" with the most common electrical type in trained dataset
df_test[df_test["Mas Vnr Type"].isnull()]
# Out:
#       Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 865  868  907260030           60        RL          70.0      8749   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 865  N.A.       Reg          Lvl    AllPub     Inside        Gtl      CollgCr
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 865        Norm        Norm      1Fam      2Story             7             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 865        2002            2002      Gable   CompShg      VinylSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 865      VinylSd          NaN           NaN         Gd         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 865        Gd        TA            No            Unf             0
#
# ...

# %%
# Check which "Mas Vnr Type" type is the most common in trained dataset
df["Mas Vnr Type"].value_counts()
# Out:
# N.A.       1238
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: Mas Vnr Type, dtype: int64

# %%
df_test["Mas Vnr Type"].value_counts()
# Out:
# None       534
# BrkFace    250
# Stone       80
# BrkCmn      12
# CBlock       1
# Name: Mas Vnr Type, dtype: int64

# %%
# Since the most common "Mas Vnr Type" is N.A., we shall fill in "Mas Vnr Type" as "N.A." & "Mass Vnr Area" as 0
df_test.loc[df_test["Mas Vnr Type"].isnull(), "Mas Vnr Type"] = "N.A."
df_test.loc[df_test["Mas Vnr Area"].isnull(), "Mas Vnr Area"] = 0.0

# %%
display_null(df_test)
# Out:
# Lot Frontage     160
# Garage Yr Blt     45
# dtype: int64

# %%
len(df_test.loc[df_test["Garage Yr Blt"] == df_test["Year Built"], ]) / len(df_test)
# Out:
# 0.7539863325740319

# %% [markdown]
# As shown from above, 76% of the house built the garage in the same year as they built the house. <br>
# Hence, we should replace the missing "Garage Yr Blt" with "Year Built".

# %%
df_test.loc[df_test["Garage Yr Blt"].isnull(), "Garage Yr Blt"] = df_test["Year Built"]

# %%
display_null(df_test)
# Out:
# Lot Frontage    160
# dtype: int64

# %% [markdown]
# **Observations:** <br>
# There are 160 missing data for 'Lot Frontage' <br>
# Lot Frontage (Continuous): Linear feet of street connected to property <br>
# Missing lot frontage simply means that there is no street connected to the property, hence value = 0

# %%
df_test.loc[df_test["Lot Frontage"].isnull(), "Lot Frontage"] = 0

# %%
# confirm that dataset has no more null value
display_null(df_test)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # 03. ORDINAL DATA ENCODING

# %% [markdown]
# Before we can run our analysis, we need to encode our ordinal features according to the DataDictionary. <br>
# Ordinal data is a categorical, statistical data type where the variables have natural, ordered categories. <br>
# For example: Small < Medium < Large, Low < Medium < High

# %%
# To encode the ordinal features
def ordinal_feature(df):
    df['Lot Shape'] = df['Lot Shape'].map({'IR3': 1, 'IR2': 2, 'IR1': 3, 'Reg': 4})
    df['Utilities'] = df['Utilities'].map({'ELO': 1, 'NoSeWa': 2, 'NoSewr': 3, 'AllPub': 4})
    df['Land Slope'] = df['Land Slope'].map({"Sev": 1, "Mod": 2, "Gtl": 3})
    df['Exter Qual'] = df['Exter Qual'].map({'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Exter Cond'] = df['Exter Cond'].map({'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Bsmt Qual'] = df['Bsmt Qual'].map({'N.A.': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Bsmt Cond'] = df['Bsmt Cond'].map({'N.A.': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Bsmt Exposure'] = df['Bsmt Exposure'].map({'N.A.': 0, 'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4})
    df['BsmtFin Type 1'] = df['BsmtFin Type 1'].map({'N.A.': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6})
    df['BsmtFin Type 2'] = df['BsmtFin Type 2'].map({'N.A.': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6})
    df['Heating QC'] = df['Heating QC'].map({'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Electrical'] = df['Electrical'].map({"Mix": 1, "FuseP": 2, "FuseF": 3, "FuseA": 4, "SBrkr": 5})
    df['Kitchen Qual'] = df['Kitchen Qual'].map({'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Functional'] = df['Functional'].map({"Sal": 1, "Sev": 2, "Maj2": 3, "Maj1": 4, "Mod": 5, "Min2": 6, "Min1": 7, "Typ": 8})
    df['Fireplace Qu'] = df['Fireplace Qu'].map({'N.A.': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Garage Finish'] = df['Garage Finish'].map({'N.A.': 0, 'Unf': 1, 'RFn': 2, 'Fin': 3})
    df['Garage Qual'] = df['Garage Qual'].map({'N.A.': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Garage Cond'] = df['Garage Cond'].map({'N.A.': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5})
    df['Paved Drive'] = df['Paved Drive'].map({"N": 1, "P": 2, "Y": 3})
    df['Pool QC'] = df['Pool QC'].map({"N.A.": 0, "Fa": 1, "TA": 2, "Gd": 3, "Ex": 4})
    df['Fence'] = df['Fence'].map({"N.A.": 0, "MnWw": 1, "GdWo": 2, "MnPrv": 3, "GdPrv": 4})

# %%
ordinal_feature(df)
ordinal_feature(df_test)

# %% [markdown]
# # 04. SUMMARY

# %% [markdown]
# **DATASETS:**
# 1. There are 2051 rows in training datasets and 878 rows in testing dataset
# 2. There are 80 features in this datasets, which could lead to modell overfitting
# 3. Most of the datas in both training & testing are flagged as missing value (NaN), however, they are actually N.A.
# 4. Some of the 'Garage Yr Blt' datas are missing. It is replaced as 'Year Built' as 76% of the house built the garage in the same year as they built the house.
# 5. Some of the data are missing lot frontage, however it simply means that there is no street connected to the property, hence the value is replaced as 0
# 6. Ordinal features are converted to numbers for further data analysis

# %% [markdown]
# # 05. EXPORT CLEANED DATA

# %%
df.to_csv('../cleaned datasets/train_1.csv', index=False)
df_test.to_csv('../cleaned datasets/test_1.csv', index=False)
